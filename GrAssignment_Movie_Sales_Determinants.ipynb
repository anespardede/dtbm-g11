# %% [markdown]
# <h1>Exploring the datasets</h1>

# %% [markdown]
# Author of this notebook: Resia S. Kilic

# %%
# Importing pandas to use its functions
import pandas as pd

# %%
# Assigning the dataset local path to a variable
# Reading the excel file with pandas
sales_dt = pd.read_excel(r"C:\Users\Gebruiker\Downloads\Data Files\sales.xlsx")
metaclean_dt = pd.read_excel(r"C:\Users\Gebruiker\Downloads\Data Files\metaClean43Brightspace.xlsx")
user_reviews_dt = pd.read_excel(r"C:\Users\Gebruiker\Downloads\Data Files\UserReviewsClean43LIWC.xlsx")
expert_reviews_dt = pd.read_excel(r"C:\Users\Gebruiker\Downloads\Data Files\ExpertReviewsClean43LIWC.xlsx")

# Viewining the column names and their data type
sales_dt.info()
metaclean_dt.info()
user_reviews_dt.info()
expert_reviews_dt.info()

# Viewing the first five rows of each dataset
sales_dt.head()
metaclean_dt.head()
user_reviews_dt.head()
expert_reviews_dt.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30612 entries, 0 to 30611
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   year                      30612 non-null  int64
#  1   release_date              30612 non-null  str
#  2   title                     30604 non-null  object
#  3   genre                     28908 non-null  str
#  4   international_box_office  21575 non-null  float64
#  5   domestic_box_office       11884 non-null  float64
#  6   worldwide_box_office      21575 non-null  float64
#  7   production_budget         4480 non-null   float64
#  8   Unnamed: 8                0 non-null      float64
#  9   opening_weekend           10929 non-null  float64
#  10  theatre_count             10963 non-null  float64
#  11  avg run per theatre       10952 non-null  float64
#  12  runtime                   24559 non-null  float64
#  13  keywords                  12517 non-null  object
# ...

# %% [markdown]
# <h3>Profile MetaClean and Sales dataset</h3>

# %%
# Checking row counts of Sales and Metaclean
print("MetaClean rows:", len(metaclean_dt))
print("Sales rows:", len(sales_dt))

# Checking missing values
print("MetaClean missing values:\n" , metaclean_dt.isnull().sum())
print("Sales missing values:\n" , sales_dt.isnull().sum())
# Out:
# MetaClean rows: 11364
# Sales rows: 30612
# MetaClean missing values:
#  url             0
# title           0
# studio        350
# rating       1067
# runtime       255
# cast         3702
# director       14
# genre          20
# summary      5897
# awards       6977
# metascore       0
# userscore    2105
# RelDate         0
# dtype: int64
# Sales missing values:
#  year                            0
# release_date                    0
# title                           8
# genre                        1704
# international_box_office     9037
# domestic_box_office         18728
# worldwide_box_office         9037
# production_budget           26132
# Unnamed: 8                  30612
# opening_weekend             19683
# theatre_count               19649
# avg run per theatre         19660
# runtime                      6053
# keywords                    18095
# creative_type                3945
# url                             0
# dtype: int64
